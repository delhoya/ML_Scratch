# %%
import pandas as pd
doc = pd.read_csv("REALESTATE/train.csv", encoding='utf-8-sig')

# %%
doc.head()
# Out:
#    transaction_id  apartment_id   city dong   jibun       apt  \
# 0               0          7622  서울특별시  신교동    6-13  신현(101동)
# 1               1          5399  서울특별시  필운동     142    사직파크맨션
# 2               2          3578  서울특별시  필운동   174-1    두레엘리시안
# 3               3         10957  서울특별시  내수동      95     파크팰리스
# 4               4         10639  서울특별시  내수동  110-15      킹스매너
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1     필운동 142 사직파크맨션               99.17                1973
# 2   필운동 174-1 두레엘리시안               84.74                2007
# 3       내수동 95 파크팰리스              146.39                2003
# 4    내수동 110-15 킹스매너              194.43                2004
#
#    transaction_year_month transaction_date  floor  transaction_real_price
# 0                  200801            21~31      2                   37500
# 1                  200801             1~10      6                   20000
# ...

# %%
doc.tail()
# Out:
#          transaction_id  apartment_id   city     dong jibun         apt  \
# 1216548         1234823          9578  부산광역시  정관읍 용수리  1387  정관 동일스위트1차
# 1216549         1234824          9578  부산광역시  정관읍 용수리  1387  정관 동일스위트1차
# 1216550         1234825          9578  부산광역시  정관읍 용수리  1387  정관 동일스위트1차
# 1216551         1234826          9586  부산광역시  정관읍 용수리  1364   정관신도시롯데캐슬
# 1216552         1234827          9578  부산광역시  정관읍 용수리  1387  정관 동일스위트1차
#
#                          addr_kr  exclusive_use_area  year_of_completion  \
# 1216548  정관읍 용수리 1387 정관 동일스위트1차             59.8245                2012
# 1216549  정관읍 용수리 1387 정관 동일스위트1차             84.9923                2012
# 1216550  정관읍 용수리 1387 정관 동일스위트1차             84.9923                2012
# 1216551   정관읍 용수리 1364 정관신도시롯데캐슬            101.7400                2008
# 1216552  정관읍 용수리 1387 정관 동일스위트1차             84.9923                2012
#
#          transaction_year_month transaction_date  floor  \
# ...

# %%
doc.shape
# Out:
# (1216553, 13)

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1216553 entries, 0 to 1216552
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   transaction_id          1216553 non-null  int64
#  1   apartment_id            1216553 non-null  int64
#  2   city                    1216553 non-null  object
#  3   dong                    1216553 non-null  object
#  4   jibun                   1216553 non-null  object
#  5   apt                     1216553 non-null  object
#  6   addr_kr                 1216553 non-null  object
#  7   exclusive_use_area      1216553 non-null  float64
#  8   year_of_completion      1216553 non-null  int64
#  9   transaction_year_month  1216553 non-null  int64
#  10  transaction_date        1216553 non-null  object
#  11  floor                   1216553 non-null  int64
#  12  transaction_real_price  1216553 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# ...

# %%
doc.columns
# Out:
# Index(['transaction_id', 'apartment_id', 'city', 'dong', 'jibun', 'apt',
#        'addr_kr', 'exclusive_use_area', 'year_of_completion',
#        'transaction_year_month', 'transaction_date', 'floor',
#        'transaction_real_price'],
#       dtype='object')

# %%
doc.describe()
# Out:
#        transaction_id  apartment_id  exclusive_use_area  year_of_completion  \
# count    1.216553e+06  1.216553e+06        1.216553e+06        1.216553e+06
# mean     6.091530e+05  6.299685e+03        7.816549e+01        1.998297e+03
# std      3.526198e+05  3.581169e+03        2.915113e+01        8.941347e+00
# min      0.000000e+00  0.000000e+00        9.260000e+00        1.961000e+03
# 25%      3.041380e+05  3.345000e+03        5.976000e+01        1.993000e+03
# 50%      6.082760e+05  5.964000e+03        8.241000e+01        1.999000e+03
# 75%      9.124140e+05  9.436000e+03        8.497000e+01        2.005000e+03
# max      1.234827e+06  1.265800e+04        4.243200e+02        2.017000e+03
#
#        transaction_year_month         floor  transaction_real_price
# count            1.216553e+06  1.216553e+06            1.216553e+06
# mean             2.012984e+05  9.343291e+00            3.822769e+04
# std              2.905732e+02  6.606500e+00            3.104898e+04
# ...

# %%
doc.corr()
# Out:
#                         transaction_id  apartment_id  exclusive_use_area  \
# transaction_id                1.000000     -0.050520            0.039815
# apartment_id                 -0.050520      1.000000            0.015098
# exclusive_use_area            0.039815      0.015098            1.000000
# year_of_completion            0.011021     -0.042868            0.168540
# transaction_year_month        0.205657     -0.002918            0.019041
# floor                         0.061906     -0.011769            0.134716
# transaction_real_price       -0.120734      0.017576            0.561563
#
#                         year_of_completion  transaction_year_month     floor  \
# transaction_id                    0.011021                0.205657  0.061906
# apartment_id                     -0.042868               -0.002918 -0.011769
# exclusive_use_area                0.168540                0.019041  0.134716
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(5,5))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns

plt.figure(figsize=(5,5))
sns.heatmap(data = doc.corr(), annot=True, fmt = '.2f', linewidths=0.5, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
doc_seoul = doc[doc['city'] == '서울특별시']
doc_seoul.head()
# Out:
#    transaction_id  apartment_id   city dong   jibun       apt  \
# 0               0          7622  서울특별시  신교동    6-13  신현(101동)
# 1               1          5399  서울특별시  필운동     142    사직파크맨션
# 2               2          3578  서울특별시  필운동   174-1    두레엘리시안
# 3               3         10957  서울특별시  내수동      95     파크팰리스
# 4               4         10639  서울특별시  내수동  110-15      킹스매너
#
#              addr_kr  exclusive_use_area  year_of_completion  \
# 0  신교동 6-13 신현(101동)               84.82                2002
# 1     필운동 142 사직파크맨션               99.17                1973
# 2   필운동 174-1 두레엘리시안               84.74                2007
# 3       내수동 95 파크팰리스              146.39                2003
# 4    내수동 110-15 킹스매너              194.43                2004
#
#    transaction_year_month transaction_date  floor  transaction_real_price
# 0                  200801            21~31      2                   37500
# 1                  200801             1~10      6                   20000
# ...

# %%
doc_seoul.corr()
# Out:
#                         transaction_id  apartment_id  exclusive_use_area  \
# transaction_id                1.000000     -0.043092            0.050198
# apartment_id                 -0.043092      1.000000            0.000913
# exclusive_use_area            0.050198      0.000913            1.000000
# year_of_completion           -0.034722     -0.097517            0.118458
# transaction_year_month        0.419598     -0.022335            0.039646
# floor                         0.006679     -0.013484            0.104238
# transaction_real_price        0.257988     -0.016458            0.668717
#
#                         year_of_completion  transaction_year_month     floor  \
# transaction_id                   -0.034722                0.419598  0.006679
# apartment_id                     -0.097517               -0.022335 -0.013484
# exclusive_use_area                0.118458                0.039646  0.104238
# ...

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data = doc_seoul.corr(), annot=True, fmt = '.2f', linewidths=0.5, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
# city 컬럼에 서울 특별시 할당 
is_seoul = doc['city'] == '서울특별시'

# dong 컬럼에 등촌동 할당 
# 그 결과를 새로운 변수에 할당.
find_dong = doc['dong'] == '등촌동'
# 두가지 조건를 동시에 충족하는 데이터를 필터링하여 새로운 변수에 저장 (AND)(&)
seoul_dong = doc[is_seoul & find_dong]

# 결과를 출력.
seoul_dong.head()
# Out:
#         transaction_id  apartment_id   city dong   jibun           apt  \
# 336798          336798          3697  서울특별시  등촌동  633-28      등촌5차보람쉬움
# 336799          336799          9793  서울특별시  등촌동     702          주공10
# 336800          336800          5204  서울특별시  등촌동   691-3            부영
# 336801          336801          9810  서울특별시  등촌동     688           주공3
# 336802          336802          3696  서울특별시  등촌동     687  등촌1,2단지주공아파트
#
#                      addr_kr  exclusive_use_area  year_of_completion  \
# 336798   등촌동 633-28 등촌5차보람쉬움               84.97                2004
# 336799          등촌동 702 주공10               58.14                1995
# 336800          등촌동 691-3 부영               80.64                1994
# 336801           등촌동 688 주공3               58.14                1995
# 336802  등촌동 687 등촌1,2단지주공아파트               41.85                1995
#
#         transaction_year_month transaction_date  floor  transaction_real_price
# ...

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data = seoul_dong.corr(), annot=True, fmt = '.2f', linewidths=0.5, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
# city 컬럼에 서울 특별시 할당 
is_seoul = doc['city'] == '서울특별시'

# dong 컬럼에 등촌동 할당 
# 그 결과를 새로운 변수에 할당.
find_dong = doc['dong'] == '등촌동'
year_AF2000 = doc['year_of_completion'] >= 2010
year_BF2000 = doc['year_of_completion'] < 2010
# 조건를 동시에 충족하는 데이터를 필터링하여 새로운 변수에 저장 (AND)(&)
seoul_dong_AF = doc[is_seoul & find_dong & year_AF2010]

# 결과를 출력.
seoul_dong_AF.head()
# Out:
#         transaction_id  apartment_id   city dong   jibun    apt  \
# 349145          349145         10377  서울특별시  등촌동     651  청솔펠리체
# 349146          349146         10377  서울특별시  등촌동     651  청솔펠리체
# 349754          349754           987  서울특별시  등촌동  646-29  계명위너스
# 349758          349758           987  서울특별시  등촌동  646-29  계명위너스
# 349933          349933           987  서울특별시  등촌동  646-29  계명위너스
#
#                  addr_kr  exclusive_use_area  year_of_completion  \
# 349145     등촌동 651 청솔펠리체               83.12                2011
# 349146     등촌동 651 청솔펠리체               83.51                2011
# 349754  등촌동 646-29 계명위너스               29.97                2011
# 349758  등촌동 646-29 계명위너스               29.76                2011
# 349933  등촌동 646-29 계명위너스               29.97                2011
#
#         transaction_year_month transaction_date  floor  transaction_real_price
# 349145                  201111             1~10      3                   36000
# ...

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data = seoul_dong_AF.corr(), annot=True, fmt = '.2f', linewidths=0.5, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
# city 컬럼에 서울 특별시 할당 
is_seoul = doc['city'] == '서울특별시'

# dong 컬럼에 등촌동 할당 
# 그 결과를 새로운 변수에 할당.
find_dong = doc['dong'] == '등촌동'
year_AF2010 = doc['year_of_completion'] >= 2010
year_BF2010 = doc['year_of_completion'] < 2010
# 조건를 동시에 충족하는 데이터를 필터링하여 새로운 변수에 저장 (AND)(&)
seoul_dong_BF = doc[is_seoul & find_dong & year_BF2010]

# 결과를 출력.
seoul_dong_BF.head()
# Out:
#         transaction_id  apartment_id   city dong   jibun           apt  \
# 336798          336798          3697  서울특별시  등촌동  633-28      등촌5차보람쉬움
# 336799          336799          9793  서울특별시  등촌동     702          주공10
# 336800          336800          5204  서울특별시  등촌동   691-3            부영
# 336801          336801          9810  서울특별시  등촌동     688           주공3
# 336802          336802          3696  서울특별시  등촌동     687  등촌1,2단지주공아파트
#
#                      addr_kr  exclusive_use_area  year_of_completion  \
# 336798   등촌동 633-28 등촌5차보람쉬움               84.97                2004
# 336799          등촌동 702 주공10               58.14                1995
# 336800          등촌동 691-3 부영               80.64                1994
# 336801           등촌동 688 주공3               58.14                1995
# 336802  등촌동 687 등촌1,2단지주공아파트               41.85                1995
#
#         transaction_year_month transaction_date  floor  transaction_real_price
# ...

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data = seoul_dong_BF.corr(), annot=True, fmt = '.2f', linewidths=0.5, cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
seoul_dong_AF.apt
# Out:
# 349145        청솔펠리체
# 349146        청솔펠리체
# 349754        계명위너스
# 349758        계명위너스
# 349933        계명위너스
#              ...
# 375495     풍성애뜨란아파트
# 1140166    풍성애뜨란아파트
# 1140337       계명위너스
# 1140380       청솔펠리체
# 1140688       청솔펠리체
# Name: apt, Length: 65, dtype: object

# %%
seoul_dong_AF.drop_duplicates(['apt'])
# Out:
#         transaction_id  apartment_id   city dong   jibun       apt  \
# 349145          349145         10377  서울특별시  등촌동     651     청솔펠리체
# 349754          349754           987  서울특별시  등촌동  646-29     계명위너스
# 372517          372517         11100  서울특별시  등촌동  654-79  풍성애뜨란아파트
#
#                     addr_kr  exclusive_use_area  year_of_completion  \
# 349145        등촌동 651 청솔펠리체               83.12                2011
# 349754     등촌동 646-29 계명위너스               29.97                2011
# 372517  등촌동 654-79 풍성애뜨란아파트               72.04                2016
#
#         transaction_year_month transaction_date  floor  transaction_real_price
# 349145                  201111             1~10      3                   36000
# 349754                  201202            21~29      4                   17800
# 372517                  201607             1~10      5                   37500
